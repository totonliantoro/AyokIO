# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('surveys.csv')

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_species = surveys_df['species_id']
surveys_species.head()
# Out:
# 0    NL
# 1    NL
# 2    DM
# 3    DM
# 4    DM
# Name: species_id, dtype: object

# %%
surveys_df[['species_id','plot_id']].head ()
# Out:
#   species_id  plot_id
# 0         NL        2
# 1         NL        3
# 2         DM        2
# 3         DM        7
# 4         DM        3

# %%
surveys_df['species_id'].head ()
# Out:
# 0    NL
# 1    NL
# 2    DM
# 3    DM
# 4    DM
# Name: species_id, dtype: object

# %%
surveys_df[['species_id','plot_id']].head ()
# Out:
#   species_id  plot_id
# 0         NL        2
# 1         NL        3
# 2         DM        2
# 3         DM        7
# 4         DM        3

# %%
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.loc[[0,10],:]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
surveys_df.loc [0,['species_id', 'plot_id', 'weight']]
# Out:
# species_id     NL
# plot_id         2
# weight        NaN
# Name: 0, dtype: object

# %%
surveys_df.loc[[10],:]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 10     NaN

# %%
surveys_df.loc[[0,10,35549],:]
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 0            1.0    7.0  16.0  1977.0      2.0         NL    M
# 10          11.0    7.0  16.0  1977.0      5.0         DS    F
# 35549        NaN    NaN   NaN     NaN      NaN        NaN  NaN
#
#        hindfoot_length  weight
# 0                 32.0     NaN
# 10                53.0     NaN
# 35549              NaN     NaN

# %%
type (surveys_df.loc[[0,10,35549],:])
# Out:
# pandas.core.frame.DataFrame

# %%
type (surveys_df.iloc[2,6])
# Out:
# str

# %% [raw]
# surveys_df[surveys_df.year == 2002].head()

# %%
surveys_df.year.head()
# Out:
# 0    1977
# 1    1977
# 2    1977
# 3    1977
# 4    1977
# Name: year, dtype: int64

# %%
surveys_df[surveys_df.year != 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df[surveys_df.year != 2002].head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df[(surveys_df.year >= 1980)&(surveys_df.year <= 1985)].head()
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2270       2271      1   15  1980        8         DO   M             35.0
# 2271       2272      1   15  1980       11         PF   F             16.0
# 2272       2273      1   15  1980       18         DM   F             34.0
# 2273       2274      1   15  1980       11         DM   M             38.0
# 2274       2275      1   15  1980        8         DO   F             33.0
#
#       weight
# 2270    53.0
# 2271    10.0
# 2272    33.0
# 2273    37.0
# 2274    29.0

# %%
surveys_df[(surveys_df.year >= 1999)&(surveys_df.weight <= 8)].tail()
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 35100      35101     11   10  2002        9         PF   M             14.0
# 35171      35172     11   10  2002       14         PF   F             15.0
# 35300      35301     12    8  2002        4         PF   M             13.0
# 35307      35308     12    8  2002        6         PF   F             16.0
# 35505      35506     12   31  2002        6         PF   M             13.0
#
#        weight
# 35100     7.0
# 35171     7.0
# 35300     6.0
# 35307     6.0
# 35505     8.0

# %%
type (surveys_df[(surveys_df.year >= 1999)&(surveys_df.weight <= 8)])
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df[surveys_df['species_id'].isin(['PF'])].head()
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 5           6      7   16  1977        1         PF    M             14.0
# 9          10      7   16  1977        6         PF    F             20.0
# 18         19      7   16  1977        4         PF  NaN              NaN
# 68         69      8   19  1977        2         PF    M             15.0
# 73         74      8   19  1977        8         PF    M             12.0
#
#     weight
# 5      NaN
# 9      NaN
# 18     NaN
# 68     8.0
# 73     7.0

# %%
surveys_df[surveys_df.weight >=0].tail()
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35546    14.0
# 35547    51.0

# %%
surveys_df[surveys_df['species_id'].isin(['PB', 'RM'])& surveys_df.weight >=0].head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df[~surveys_df['species_id'].isin(['PB', 'RM'])& surveys_df.weight >=0].tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df[~surveys_df['weight'].isnull() & surveys_df.weight >=0].tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df [(surveys_df.year >= 1980)& (surveys_df<= 1985) & ~(surveys_df['species_id'].isnull())].tail()

# %%
surveys_df['species_id'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: species_id, dtype: bool

# %%
pd.isnull(surveys_df).head()
# Out:
#   record_id  month    day   year plot_id species_id    sex hindfoot_length  \
# 0     False  False  False  False   False      False  False           False
# 1     False  False  False  False   False      False  False           False
# 2     False  False  False  False   False      False  False           False
# 3     False  False  False  False   False      False  False           False
# 4     False  False  False  False   False      False  False           False
#
#   weight
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df [pd.isnull(surveys_df)].head()
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0        NaN    NaN  NaN   NaN      NaN        NaN  NaN              NaN
# 1        NaN    NaN  NaN   NaN      NaN        NaN  NaN              NaN
# 2        NaN    NaN  NaN   NaN      NaN        NaN  NaN              NaN
# 3        NaN    NaN  NaN   NaN      NaN        NaN  NaN              NaN
# 4        NaN    NaN  NaN   NaN      NaN        NaN  NaN              NaN
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df [(pd.isnull(surveys_df).any(axis=1))].head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df [~(pd.isnull(surveys_df).any(axis=1))].head()
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62         63      8   19  1977        3         DM   M             35.0
# 63         64      8   19  1977        7         DM   M             37.0
# 64         65      8   19  1977        4         DM   F             34.0
# 65         66      8   19  1977        4         DM   F             35.0
# 66         67      8   19  1977        7         DM   M             35.0
#
#     weight
# 62    40.0
# 63    48.0
# 64    29.0
# 65    46.0
# 66    36.0

# %%
#Challenge
#1 Create a new DataFrame that only contains observations with sex values that are not female or male. 
#assign each sex value in the new DataFrame to a new value of 'x'. Determine the number of null values in the subset.
#2 Create a new DataFrame that contains only observations that are of sex male or female 
#and where weight values are greater than 0. Create a stacked bar plot of average weight 
#by plot with male vs female values stacked for each plot.

# %%
#1
new_survey_df = surveys_df[pd.isnull (surveys_df['sex'])]

# %%
new_survey_df.head()
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 13         14      7   16  1977        8         DM  NaN              NaN
# 18         19      7   16  1977        4         PF  NaN              NaN
# 33         34      7   17  1977       17         DM  NaN              NaN
# 56         57      7   18  1977       22         DM  NaN              NaN
# 76         77      8   19  1977        4         SS  NaN              NaN
#
#     weight
# 13     NaN
# 18     NaN
# 33     NaN
# 56     NaN
# 76     NaN

# %%
#1
surveys_df[pd.isnull (surveys_df['sex'])].head()
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 13         14      7   16  1977        8         DM  NaN              NaN
# 18         19      7   16  1977        4         PF  NaN              NaN
# 33         34      7   17  1977       17         DM  NaN              NaN
# 56         57      7   18  1977       22         DM  NaN              NaN
# 76         77      8   19  1977        4         SS  NaN              NaN
#
#     weight
# 13     NaN
# 18     NaN
# 33     NaN
# 56     NaN
# 76     NaN

# %%
1+1
# Out:
# 2

# %%
surveys_df = pd.read_csv('surveys.csv')

# %%
species_df = pd.read_csv('species.csv')

# %%
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveySub = surveys_df.head()

# %%
surveySub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveySubLast10 = surveys_df[-11:-1]

# %%
surveySubLast10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
#
#        weight
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# ...

# %%
surveySubLast10 = surveySubLast10.reset_index(drop=True)

# %%
surveySubLast10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35539     12   31  2002       15         SF    M             26.0
# 1      35540     12   31  2002       15         PB    F             26.0
# 2      35541     12   31  2002       15         PB    F             24.0
# 3      35542     12   31  2002       15         PB    F             26.0
# 4      35543     12   31  2002       15         PB    F             27.0
# 5      35544     12   31  2002       15         US  NaN              NaN
# 6      35545     12   31  2002       15         AH  NaN              NaN
# 7      35546     12   31  2002       15         AH  NaN              NaN
# 8      35547     12   31  2002       10         RM    F             15.0
# 9      35548     12   31  2002        7         DO    M             36.0
#
#    weight
# 0    68.0
# 1    23.0
# 2    31.0
# 3    29.0
# 4    34.0
# 5     NaN
# 6     NaN
# 7     NaN
# 8    14.0
# 9    51.0

# %%
vertical_stack = pd.concat([surveySub, surveySubLast10], axis = 1 )

# %%
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 0      35539     12   31  2002       15         SF    M             26.0
# 1      35540     12   31  2002       15         PB    F             26.0
# 2      35541     12   31  2002       15         PB    F             24.0
# 3      35542     12   31  2002       15         PB    F             26.0
# 4      35543     12   31  2002       15         PB    F             27.0
# 5      35544     12   31  2002       15         US  NaN              NaN
# 6      35545     12   31  2002       15         AH  NaN              NaN
# ...

# %%
vertical_stack.to_csv('out.csv')

# %%
#1980,1982

# %%
surveys_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-237dcd732b5d> in <module>()
# ----> 1 surveys_df
#
# NameError: name 'surveys_df' is not defined

# %%
surveys_df = pd.read_csv('surveys.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0c05001e3999> in <module>()
# ----> 1 surveys_df = pd.read_csv('surveys.csv')
#
# NameError: name 'pd' is not defined

# %%
species_df = pd.read_csv('species.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-78b8fc10369d> in <module>()
# ----> 1 species_df = pd.read_csv('species.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
species_df = pd.read_csv('species.csv')

# %%
surveys_df = pd.read_csv('surveys.csv')

# %%
#1980,1982

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
year80 = surveys_df[surveys_df['year']==1980]
year82 = surveys_df[surveys_df['year']==1982]

# %%
year82= year82.reset_index()
year80= year80.reset_index()

# %%
year_stack = pd.concat([year82, year80], axis = 1 )

# %%
year_stack
# Out:
#       index  record_id  month  day  year  plot_id species_id sex  \
# 0      5157       5158      1    1  1982        1         DO   F
# 1      5158       5159      1    1  1982        5         DM   F
# 2      5159       5160      1    1  1982        3         RM   F
# 3      5160       5161      1    1  1982        5         NL   F
# 4      5161       5162      1    1  1982        3         RM   F
# 5      5162       5163      1    1  1982        3         NL   F
# 6      5163       5164      1    1  1982        2         DS   F
# 7      5164       5165      1    1  1982        3         PF   M
# 8      5165       5166      1    1  1982        4         DM   M
# 9      5166       5167      1    1  1982        2         DM   M
# 10     5167       5168      1    1  1982        4         DS   M
# 11     5168       5169      1    1  1982        5         DM   F
# 12     5169       5170      1    1  1982        6         DS   F
# ...

# %%
surveySub = surveys_df.head()

# %%
surveySub =surveys_df.head(10)
speciesSub = species_df.head (10)

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
species_df.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
merged_inner = pd.merge(left=species_df, right=surveySub, left_on = 'species_id',right_on='species_id')

# %%
merged_inner
# Out:
#   species_id        genus   species    taxa  record_id  month  day  year  \
# 0         DM    Dipodomys  merriami  Rodent          3      7   16  1977
# 1         DM    Dipodomys  merriami  Rodent          4      7   16  1977
# 2         DM    Dipodomys  merriami  Rodent          5      7   16  1977
# 3         DM    Dipodomys  merriami  Rodent          8      7   16  1977
# 4         DM    Dipodomys  merriami  Rodent          9      7   16  1977
# 5         NL      Neotoma  albigula  Rodent          1      7   16  1977
# 6         NL      Neotoma  albigula  Rodent          2      7   16  1977
# 7         PE   Peromyscus  eremicus  Rodent          7      7   16  1977
# 8         PF  Perognathus    flavus  Rodent          6      7   16  1977
# 9         PF  Perognathus    flavus  Rodent         10      7   16  1977
#
#    plot_id sex  hindfoot_length  weight
# 0        2   F             37.0     NaN
# 1        7   M             36.0     NaN
# 2        3   M             35.0     NaN
# ...

# %%
merged_left = pd.merge (left=surveySub, right= species_df, 
                       how='left', left_on='species_id', right_on ='species_id')

# %%
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight        genus   species    taxa
# 0     NaN      Neotoma  albigula  Rodent
# 1     NaN      Neotoma  albigula  Rodent
# 2     NaN    Dipodomys  merriami  Rodent
# ...

# %%
print(merged_inner.shape)
print(merged_left.shape)
# Out:
# (10, 12)
# (10, 12)

# %%
merged_inner.groupby('plot_id').describe()
# Out:
#                 day  hindfoot_length  month  record_id  weight    year
# plot_id
# 1       count   3.0         3.000000    3.0   3.000000     0.0     3.0
#         mean   16.0        28.333333    7.0   7.666667     NaN  1977.0
#         std     0.0        12.503333    0.0   1.527525     NaN     0.0
#         min    16.0        14.000000    7.0   6.000000     NaN  1977.0
#         25%    16.0        24.000000    7.0   7.000000     NaN  1977.0
#         50%    16.0        34.000000    7.0   8.000000     NaN  1977.0
#         75%    16.0        35.500000    7.0   8.500000     NaN  1977.0
#         max    16.0        37.000000    7.0   9.000000     NaN  1977.0
# 2       count   3.0         2.000000    3.0   3.000000     0.0     3.0
#         mean   16.0        34.500000    7.0   3.666667     NaN  1977.0
#         std     0.0         3.535534    0.0   3.055050     NaN     0.0
#         min    16.0        32.000000    7.0   1.000000     NaN  1977.0
# ...

# %%
merged_inner.groupby('sex').count()
# Out:
#      species_id  genus  species  taxa  record_id  month  day  year  plot_id  \
# sex
# F             4      4        4     4          4      4    4     4        4
# M             6      6        6     6          6      6    6     6        6
#
#      hindfoot_length  weight
# sex
# F                  3       0
# M                  6       0

# %%
merged_inner.groupby('species_id')['genus'].count().plot(kind='bar')

# %%
# %matplotlib inline

# %%
merged_inner.groupby('species_id')['genus'].count().plot(kind='bar')

# %%
merged_inner.groupby('plot_id')['genus'].count().plot(kind='bar')

# %%
#Find mean weight grouping by subsetting only the rows containing the year 1982 and 
a factor (in the example above it is 'sex')
